# %% [markdown]
# Sales Analysis workbook by Paul Owe
#
# This is a walkthrough of how I would use Pandas & Matplotlib to analyze and answer business questions about 12 months worth of sales data. The data contains hundreds of thousands of electronics store purchases broken down by month, product type, cost, purchase address, etc.

# %%
import pandas as pd
import os

# %% [markdown]
# # Merging the 12 months of sales data into a single CSV file

# %%
df = pd.read_csv("./data/Sales_April_2019.csv") # data for April
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  2004-07-19 22:30     682 Chestnut St, Boston, MA 02215
# 2  2004-12-19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  2004-12-19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# put all file objects in a list 

files = [file for file in os.listdir('./data')]

#concatenate all these files

all_months_data = pd.DataFrame() # empty df to hold your concatenated data

for file in files:
    df = pd.read_csv('./data/'+file)
    all_months_data = pd.concat([all_months_data, df])

all_months_data.to_csv('all_data.csv', index=False) # index false ignores that first column beside Orderid

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ## What was the best month for sales? How much was earned that month?

# %% [markdown]
# To answer this question we will need to
# - Multiply qty x price and
# - group results by month
#
# Approach is to create specific column for:
# - Month, and
# - Sales

# %%
# Clean Data - Find all Nan in data set

nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()

#Drop all NaN

all_data = all_data.dropna(how='all')

# %% [markdown]
# So, we see that our data was dirty because our concatenation process also added the column names over and over again.
# To remove these we can simply copy the filtering code and modify it a little bit

# %%
#index all_data[based on a condition]
all_data = all_data[all_data['Month'] != 'Or']
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
# Month column
all_data['Month'] = all_data['Order Date'].str[0:2]
pd.to_numeric(all_data['Month'])
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
# Step 1: Multiply qty by price

all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95

# %% [markdown]
# Now, to answer this question, we will group by month and sum up the sales quantities

# %%
all_data.groupby('Month').sum()
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 01                10903  1.811768e+06  1.822257e+06
# 02                13449  2.188885e+06  2.202022e+06
# 03                17005  2.791208e+06  2.807100e+06
# 04                12356  2.056151e+06  2.071078e+06
# 05                18638  3.124570e+06  3.142047e+06
# 06                15253  2.562026e+06  2.577802e+06
# 07                16072  2.632540e+06  2.647776e+06
# 08                13448  2.230345e+06  2.244468e+06
# 09                13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06
# 20                 8231  1.322075e+06  1.330151e+06

# %%
wrong_month_data = all_data[all_data['Month'] == '20']
wrong_month_data.head()
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 25118   176559  Bose SoundSport Headphones                 1       99.99
# 25119   176560                Google Phone                 1      600.00
# 25120   176560            Wired Headphones                 1       11.99
# 25123   176563  Bose SoundSport Headphones                 1       99.99
# 25124   176564        USB-C Charging Cable                 1       11.95
#
#              Order Date                      Purchase Address Month   Sales
# 25118  2004-07-19 22:30     682 Chestnut St, Boston, MA 02215    20   99.99
# 25119  2004-12-19 14:38  669 Spruce St, Los Angeles, CA 90001    20  600.00
# 25120  2004-12-19 14:38  669 Spruce St, Los Angeles, CA 90001    20   11.99
# 25123   2004-02-19 7:46      668 Center St, Seattle, WA 98101    20   99.99
# 25124  2004-12-19 10:58       790 Ridge St, Atlanta, GA 30301    20   11.95

# %% [markdown]
# Looks like some of the dates were not formatted properly so we have a '20th month'
# We will fix this below and rerun our groupby month and sum sales function again

# %%
wrong_month_data['Month'] = wrong_month_data['Order Date'].str[5:7]

wrong_month_data.head()

all_data[all_data['Month'] == '20'] = wrong_month_data
results = all_data.groupby('Month').sum()
# Out:
# /Users/pcowe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

months = range(1, 13)
plt.ylabel('Sales')
plt.xlabel('Months')
plt.bar(months, results['Sales'])
plt.show()

# %% [markdown]
# These results are interesting. As a data scientist I would look further into why theses results are like that. Maybe December was busy because of holidays season and everyone stops spending as much in January. There could be other factors to look into..

# %% [markdown]
# # What city had the highest number of sales

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95

# %%
all_data[['Street Address', 'City', 'Postal Code']] = all_data['Purchase Address'].str.split(',', expand=True)

all_data.head()

#all_data['City']
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95
#
#   Street Address            City Postal Code
# 0  136 Church St   New York City    NY 10001
# 1     562 2nd St   New York City    NY 10001
# ...

# %% [markdown]
# So, here to make city analysis easier, we split Purchase Address to contain specific columns for address, city and postal code
# To find the highest sales by city, its essentially a group by city and sum the sales

# %%
highest_sales_by_city = all_data.groupby('City').sum()['Sales']
highest_sales_by_city
# Out:
# City
#  Atlanta          2.795499e+06
#  Austin           1.819582e+06
#  Boston           3.661642e+06
#  Dallas           2.767975e+06
#  Los Angeles      5.452571e+06
#  New York City    4.664317e+06
#  Portland         2.320491e+06
#  San Francisco    8.262204e+06
#  Seattle          2.747755e+06
# Name: Sales, dtype: float64

# %% [markdown]
# So the answer to this question is San Francisco. They have over 8.2M in revenue

# %%
cities = [city for city, unk in all_data.groupby('City')]
plt.xticks(rotation='vertical')
plt.xlabel('City')
plt.ylabel('Sales')

plt.bar(cities, highest_sales_by_city)
plt.show()

# %% [markdown]
# Again, as a data scientist we may want to go further and uncover reasons for this trend? Why is San Francisco the number one location with highest sales? Could it be the income in this city? or perhaps the because Silicon Valley would have a higher demand for technology products (this is a technology store)
#
# Would be a good idea to go further and explore this trend

# %% [markdown]
# ## What time should we display advertisements to maximize likelihood of customers buying the product?

# %% [markdown]
# The main column for analysis here is the order date. To manipulate this column pretty effortlessly we can change it from a string into a datetime object. This will give us some flexibility to work with dates and time in a 'pythonic way'
#
# Performance impact note: Using datetime objects may take up some extra memory on your machine but should be fine as long as youre not analyzing large volumes of data (terabytes, petabyte, and so on). For our purposes, we are processing yearly data, so it shouldnt be a problem.

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001    12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001    12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016    12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    12    11.95
#
#   Street Address            City Postal Code
# 0  136 Church St   New York City    NY 10001
# ...

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %% [markdown]
# So now that we have our order date column in the datetime format. We have access to a lot of convenient methods like .dt.hour
#
# Let's create an hour column

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute

all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001    12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001    12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016    12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    12    11.95
#
#   Street Address            City Postal Code  Hour  Minute
# 0  136 Church St   New York City    NY 10001     0       1
# ...

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]

#line graph - to show the number of order occurences that happened during a particular hour of the day
plt.ylabel('Number of orders')
plt.xlabel('Hour')
plt.xticks(hours) #displays all the hours
plt.grid() # displays the grid for better pinpoinitng the time of the day
plt.plot(hours, all_data.groupby(['Hour']).count())

# %% [markdown]
# This chart shows peaks at around 11am and 7pm. This means that
# - Majority of our customers across all states order around 11am or 7pm
# - The trend is from data collected over a period of one year
#
# So my recommendation would be to display ads around 11am or 7pm because this will improve the chance that customers see the ad.

# %% [markdown]
# ## What products are most often sold together?
#
# For this question we will use association rule mining. For further reading about the algorithm used here, check out
#
#     - Apriori
#     - FP Growth

# %%
#keep only duplicated Order IDs, we can use those to create itemsets.
df = all_data[all_data['Order ID'].duplicated(keep=False)] #keep=false means keep all duplicates (shift-tab to read docstring)

df['Grouped'] =  df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df.head()
# Out:
# /Users/pcowe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone                 1      600.00
# 17   295681        USB-C Charging Cable                 1       11.95
# 18   295681  Bose SoundSport Headphones                 1       99.99
# 19   295681            Wired Headphones                 1       11.99
# 36   295698             Vareebadd Phone                 1      400.00
#
#             Order Date                     Purchase Address Month   Sales  \
# ...

# %% [markdown]
# Now one issue is that we have duplicate itemsets. So lets get rid of those duplicates

# %%
df = df[['Order ID', 'Grouped']].drop_duplicates()

df.head()
# Out:
#    Order ID                                            Grouped
# 16   295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36   295698               Vareebadd Phone,USB-C Charging Cable
# 42   295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66   295726                    iPhone,Lightning Charging Cable
# 76   295735   iPhone,Apple Airpods Headphones,Wired Headphones

# %% [markdown]
# For this, we'll use a couple new libraries to count pairs of what occurs together most frequently.
#
# Note: if you wanted to get most frequently occuring itemsets of length 3 then simply update the line to
# count.update(Counter(combinations(row_list, 3)))

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']: #each one of google phone, wired, ... entries
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ## What product sold the most? and Why?

# %%
product_group = all_data.groupby('Product').sum()['Quantity Ordered']

products = [product for product, df in all_data.groupby('Product')]

plt.ylabel(' Quantity Ordered')
plt.xlabel('Product names')
plt.xticks(rotation='vertical')
plt.bar(products, product_group)
plt.show()

# %% [markdown]
# This is the list of products that sold the most:
# - AAA batteries were the most
# - Lightning charging cable
# - USB-C
#
# and why is it more sold than LG dryers, Washing machines? My hypothesis is that because the trending products cost relatively less than dryers, washing machines, etc
#
# We will attempt to prove hypothesis by overlaying the graph with actual prices of these items to see if theres that correlation

# %%
prices = all_data.groupby('Product').mean()['Price Each']
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
# prices = all_data.groupby('Product').mean()['Price Each']
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, product_group, color='g')

ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price', color='b')
ax1.set_xticklabels(products, rotation='vertical')

plt.show()

# %% [markdown]
# Now we have a chart that has been overlayed. So if price and quantity ordered correlate (proving our hypothesis) then price should be inversely proportional to the quantity
#
# This is the case for AAA batteries or even with LG dryers and its good evdience to support my hypothesis.
